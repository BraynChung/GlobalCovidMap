# %% [markdown]
# # Covid 19 - Geospatial Data Visualisation & Analysis

# %% [markdown]
# ### Extract Latitudes & Longitudes of a location

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\brayn\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\brayn\anaconda3\lib\site-packages (from geopy) (2.0)

# %%
import geopy
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent='app')

# %%
location = geolocator.geocode('Tawau')
location.latitude, location.longitude
# Out:
# (4.2435206, 117.885331)

# %% [markdown]
# ### Data Preparation for Spatial Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
current_data = pd.read_csv(r'C:\Users\brayn\Documents\Geospatial Analysis\Covid-19\countries-aggregated.csv')
current_data.head(20)
# Out:
#           Date      Country  Confirmed  Recovered  Deaths
# 0   2020-01-22  Afghanistan          0          0       0
# 1   2020-01-23  Afghanistan          0          0       0
# 2   2020-01-24  Afghanistan          0          0       0
# 3   2020-01-25  Afghanistan          0          0       0
# 4   2020-01-26  Afghanistan          0          0       0
# 5   2020-01-27  Afghanistan          0          0       0
# 6   2020-01-28  Afghanistan          0          0       0
# 7   2020-01-29  Afghanistan          0          0       0
# 8   2020-01-30  Afghanistan          0          0       0
# 9   2020-01-31  Afghanistan          0          0       0
# 10  2020-02-01  Afghanistan          0          0       0
# 11  2020-02-02  Afghanistan          0          0       0
# 12  2020-02-03  Afghanistan          0          0       0
# 13  2020-02-04  Afghanistan          0          0       0
# 14  2020-02-05  Afghanistan          0          0       0
# 15  2020-02-06  Afghanistan          0          0       0
# 16  2020-02-07  Afghanistan          0          0       0
# 17  2020-02-08  Afghanistan          0          0       0
# 18  2020-02-09  Afghanistan          0          0       0
# 19  2020-02-10  Afghanistan          0          0       0

# %%
current_data[current_data['Country'] == 'Afghanistan']
# Out:
#            Date      Country  Confirmed  Recovered  Deaths
# 0    2020-01-22  Afghanistan          0          0       0
# 1    2020-01-23  Afghanistan          0          0       0
# 2    2020-01-24  Afghanistan          0          0       0
# 3    2020-01-25  Afghanistan          0          0       0
# 4    2020-01-26  Afghanistan          0          0       0
# ..          ...          ...        ...        ...     ...
# 811  2022-04-12  Afghanistan     178257          0    7676
# 812  2022-04-13  Afghanistan     178295          0    7676
# 813  2022-04-14  Afghanistan     178352          0    7676
# 814  2022-04-15  Afghanistan     178373          0    7676
# 815  2022-04-16  Afghanistan     178387          0    7676
#
# [816 rows x 5 columns]

# %%
df = current_data.groupby(['Country'])[['Confirmed', 'Recovered', 'Deaths']].max().reset_index()
df.head(10)
# Out:
#                Country  Confirmed  Recovered  Deaths
# 0          Afghanistan     178387      82586    7676
# 1              Albania     274462     130314    3496
# 2              Algeria     265739     118409    6874
# 3              Andorra      40709      14380     155
# 4               Angola      99194      39582    1900
# 5           Antarctica         11          0       0
# 6  Antigua and Barbuda       7535       1239     135
# 7            Argentina    9060495    4615834  128344
# 8              Armenia     422747     220438    8621
# 9            Australia    5384615      24203    6779

# %% [markdown]
# ### Fetch Geographical Coordinates of a Country

# %%
import time

lat_lon = []
geolocator = Nominatim(user_agent='app', timeout=10)

for location in df['Country']:
    time.sleep(1)
    location = geolocator.geocode(location)
    if location is None:
        lat_lon.append(np.nan)
    else:
        geo_coord = (location.latitude, location.longitude)
#  (10.7466905, -61.0840075),
#  (33.8439408, 9.400138),
#  (39.294076, 35.2316631),
#  (39.7837304, -100.445882),
#  (1.5333554, 32.2166578),
#  (49.4871968, 31.2718321),
#  (24.0002488, 53.9994829),
#  (54.7023545, -3.2765753),
#  (-32.8755548, -56.0201525),
#  (41.32373, 63.9528098),
#  (-16.5255069, 168.1069154),
#  (8.0018709, -66.1109318),
#  (15.9266657, 107.9650855),
#  (31.9049661, 35.2023413),
#  (45.7469356, 126.696493),
#  (16.3471243, 47.8915271),
#  (-14.5189121, 27.5589884),
#  (-18.4554963, 29.7468414)]

# %%
df['geo_loc'] = lat_lon

# %%
type(df['geo_loc'][0])
# Out:
# tuple

# %%
df.head(10)
# Out:
#                Country  Confirmed  Recovered  Deaths  \
# 0          Afghanistan     178387      82586    7676
# 1              Albania     274462     130314    3496
# 2              Algeria     265739     118409    6874
# 3              Andorra      40709      14380     155
# 4               Angola      99194      39582    1900
# 5           Antarctica         11          0       0
# 6  Antigua and Barbuda       7535       1239     135
# 7            Argentina    9060495    4615834  128344
# 8              Armenia     422747     220438    8621
# 9            Australia    5384615      24203    6779
#
#                       geo_loc
# 0    (33.7680065, 66.2385139)
# 1     (41.000028, 19.9999619)
# 2     (28.0000272, 2.9999825)
# 3     (42.5407167, 1.5732033)
# 4   (-11.8775768, 17.5691241)
# 5          (-72.8438691, 0.0)
# 6   (17.2234721, -61.9554608)
# 7  (-34.9964963, -64.9672817)
# 8    (40.7696272, 44.6736646)
# 9      (-24.7761086, 134.755)

# %%
# unzip geo_loc to lat, lon
lat,lon = zip(*np.array(df['geo_loc']))

# %%
type(lat)
# Out:
# tuple

# %%
df['lat'] = lat
df['lon'] = lon

# %%
df.head(10)
# Out:
#                Country  Confirmed  Recovered  Deaths  \
# 0          Afghanistan     178387      82586    7676
# 1              Albania     274462     130314    3496
# 2              Algeria     265739     118409    6874
# 3              Andorra      40709      14380     155
# 4               Angola      99194      39582    1900
# 5           Antarctica         11          0       0
# 6  Antigua and Barbuda       7535       1239     135
# 7            Argentina    9060495    4615834  128344
# 8              Armenia     422747     220438    8621
# 9            Australia    5384615      24203    6779
#
#                       geo_loc        lat         lon
# 0    (33.7680065, 66.2385139)  33.768006   66.238514
# 1     (41.000028, 19.9999619)  41.000028   19.999962
# 2     (28.0000272, 2.9999825)  28.000027    2.999983
# 3     (42.5407167, 1.5732033)  42.540717    1.573203
# 4   (-11.8775768, 17.5691241) -11.877577   17.569124
# 5          (-72.8438691, 0.0) -72.843869    0.000000
# 6   (17.2234721, -61.9554608)  17.223472  -61.955461
# 7  (-34.9964963, -64.9672817) -34.996496  -64.967282
# 8    (40.7696272, 44.6736646)  40.769627   44.673665
# 9      (-24.7761086, 134.755) -24.776109  134.755000

# %%
df.drop('geo_loc', axis=1, inplace=True)

# %%
df.head()
# Out:
#        Country  Confirmed  Recovered  Deaths        lat        lon
# 0  Afghanistan     178387      82586    7676  33.768006  66.238514
# 1      Albania     274462     130314    3496  41.000028  19.999962
# 2      Algeria     265739     118409    6874  28.000027   2.999983
# 3      Andorra      40709      14380     155  42.540717   1.573203
# 4       Angola      99194      39582    1900 -11.877577  17.569124

# %% [markdown]
# ### Create a Base Map

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\brayn\anaconda3\lib\site-packages (0.19.6)
# Requirement already satisfied: branca>=0.6.0 in c:\users\brayn\anaconda3\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\brayn\anaconda3\lib\site-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in c:\users\brayn\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\brayn\anaconda3\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\brayn\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\brayn\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\brayn\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\brayn\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\brayn\anaconda3\lib\site-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\brayn\anaconda3\lib\site-packages (from requests->folium) (2025.4.26)

# %%
import folium

# %%
folium.Map(location=[54, 15], zoom_start=2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01d2961f6f064d3b25b0eef027a7ef51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01d2961f6f064d3b25b0eef027a7ef51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01d2961f6f064d3b25b0eef027a7ef51 = L.map(
#                 &quot;map_01d2961f6f064d3b25b0eef027a7ef51&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ffe43b1e87038eeaa64480d1718474a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ffe43b1e87038eeaa64480d1718474a.addTo(map_01d2961f6f064d3b25b0eef027a7ef51);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Plot Confirmed Case using Markers

# %%
m = folium.Map(location=[54, 15], zoom_start=2)

for id, row in df.iterrows():
    folium.Marker(location=[row['lat'], row['lon']], popup=row['Confirmed']).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9b5ee8724afa8665e85be11fbbfa9f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9b5ee8724afa8665e85be11fbbfa9f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9b5ee8724afa8665e85be11fbbfa9f0 = L.map(
#                 &quot;map_e9b5ee8724afa8665e85be11fbbfa9f0&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72d90bc5bb0051a03206d0ebdbbfd99c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_72d90bc5bb0051a03206d0ebdbbfd99c.addTo(map_e9b5ee8724afa8665e85be11fbbfa9f0);
#
#
#             var marker_82c215c7e2f6ac029a8bde4c1971bd8f = L.marker(
#                 [33.7680065, 66.2385139],
#                 {
# }
#             ).addTo(map_e9b5ee8724afa8665e85be11fbbfa9f0);
#
#
#         var popup_cd069a3368d9794de95df1893e5e75a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4188e861a7c296cb43f664b7fdd4dfdd = $(`&lt;div id=&quot;html_4188e861a7c296cb43f664b7fdd4dfdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;178387&lt;/div&gt;`)[0];
#                 popup_cd069a3368d9794de95df1893e5e75a0.setContent(html_4188e861a7c296cb43f664b7fdd4dfdd);
#
#
#
#         marker_82c215c7e2f6ac029a8bde4c1971bd8f.bindPopup(popup_cd069a3368d9794de95df1893e5e75a0)
#         ;
#
#
#
#
#             var marker_c3568743b5dd0ace3d86eb4b586a4bd6 = L.marker(
#                 [41.000028, 19.9999619],
#                 {
# }
#             ).addTo(map_e9b5ee8724afa8665e85be11fbbfa9f0);
#
#
#         var popup_01134217691ff669227e88de9d273905 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d894621fe3008e6c49903caec60dcb93 = $(`&lt;div id=&quot;html_d894621fe3008e6c49903caec60dcb93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;274462&lt;/div&gt;`)[0];
#                 popup_01134217691ff669227e88de9d273905.setContent(html_d894621fe3008e6c49903caec60dcb93);
#
#
#
#         marker_c3568743b5dd0ace3d86eb4b586a4bd6.bindPopup(popup_01134217691ff669227e88de9d273905)
#         ;
#
#
#
#
#             var marker_dcd35c46904d7650a6ca9c40c72947d5 = L.marker(
#                 [28.0000272, 2.9999825],
#                 {
# }
#             ).addTo(map_e9b5ee8724afa8665e85be11fbbfa9f0);
#
#
#         var popup_85f6435cb0ae4ee60a2f1514a85cdf1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da84435289ff7ea019ffe92907768c05 = $(`&lt;div id=&quot;html_da84435289ff7ea019ffe92907768c05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;265739&lt;/div&gt;`)[0];
#                 popup_85f6435cb0ae4ee60a2f1514a85cdf1a.setContent(html_da84435289ff7ea019ffe92907768c05);
#
#
#
#         marker_dcd35c46904d7650a6ca9c40c72947d5.bindPopup(popup_85f6435cb0ae4ee60a2f1514a85cdf1a)
#         ;
#
#
#
#
#             var marker_eb4f58ec2c9283a37d68275fa5d9133c = L.marker(
#                 [42.5407167, 1.5732033],
#                 {
# }
#             ).addTo(map_e9b5ee8724afa8665e85be11fbbfa9f0);
#
#
#         var popup_c1fad42c5e84f94e8286d78c07e8acb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_755a1f30a8c1dddc10d36ed146522253 = $(`&lt;div id=&quot;html_755a1f30a8c1dddc10d36ed146522253&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;40709&lt;/div&gt;`)[0];
#                 popup_c1fad42c5e84f94e8286d78c07e8acb0.setContent(html_755a1f30a8c1dddc10d36ed146522253);
#
#
#
#         marker_eb4f58ec2c9283a37d68275fa5d9133c.bindPopup(popup_c1fad42c5e84f94e8286d78c07e8acb0)
#         ;
#
#
#
#
#             var marker_8b0335a4fd5c32889a5d2711f0c92645 = L.marker(
#                 [-11.8775768, 17.5691241],
#                 {
# }
#             ).addTo(map_e9b5ee8724afa8665e85be11fbbfa9f0);
#
#
#         var popup_bbe9f1d0018de73c74f3a70720c7a47e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d29a15416553689fe898804b9d8fe4a7 = $(`&lt;div id=&quot;html_d29a15416553689fe898804b9d8fe4a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;99194&lt;/div&gt;`)[0];
#                 popup_bbe9f1d0018de73c74f3a70720c7a47e.setContent(html_d29a15416553689fe898804b9d8fe4a7);
#
#
#
#         marker_8b0335a4fd5c32889a5d2711f0c92645.bindPopu

# %% [markdown]
# ### Plotting a Recovered & Deaths using Markers

# %%
m = folium.Map(location=[54, 15], zoom_start=2)

for id, row in df.iterrows():
    folium.Marker(location=[row['lat'], row['lon']], popup=row['Recovered']).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4a57f58baea1ce0cbbe41566361ca8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4a57f58baea1ce0cbbe41566361ca8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4a57f58baea1ce0cbbe41566361ca8b = L.map(
#                 &quot;map_a4a57f58baea1ce0cbbe41566361ca8b&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08ceb8f7cb6ccb36a9664288784d7688 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08ceb8f7cb6ccb36a9664288784d7688.addTo(map_a4a57f58baea1ce0cbbe41566361ca8b);
#
#
#             var marker_c8f3c01cc263c22e471a210e09193a8e = L.marker(
#                 [33.7680065, 66.2385139],
#                 {
# }
#             ).addTo(map_a4a57f58baea1ce0cbbe41566361ca8b);
#
#
#         var popup_c705f6d630c673423b4bf2251f2dd87e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7197dd55abaa03c2f81c27a5e765db6 = $(`&lt;div id=&quot;html_d7197dd55abaa03c2f81c27a5e765db6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;82586&lt;/div&gt;`)[0];
#                 popup_c705f6d630c673423b4bf2251f2dd87e.setContent(html_d7197dd55abaa03c2f81c27a5e765db6);
#
#
#
#         marker_c8f3c01cc263c22e471a210e09193a8e.bindPopup(popup_c705f6d630c673423b4bf2251f2dd87e)
#         ;
#
#
#
#
#             var marker_d687be37b9d08bafabdf395c36c966ff = L.marker(
#                 [41.000028, 19.9999619],
#                 {
# }
#             ).addTo(map_a4a57f58baea1ce0cbbe41566361ca8b);
#
#
#         var popup_0dbcc1e7e1cf808013edd71f02d62ef9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ece2f53738ebffdf5bc06fca366a0a5c = $(`&lt;div id=&quot;html_ece2f53738ebffdf5bc06fca366a0a5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;130314&lt;/div&gt;`)[0];
#                 popup_0dbcc1e7e1cf808013edd71f02d62ef9.setContent(html_ece2f53738ebffdf5bc06fca366a0a5c);
#
#
#
#         marker_d687be37b9d08bafabdf395c36c966ff.bindPopup(popup_0dbcc1e7e1cf808013edd71f02d62ef9)
#         ;
#
#
#
#
#             var marker_507aa3791de693dd5db458affd67e24c = L.marker(
#                 [28.0000272, 2.9999825],
#                 {
# }
#             ).addTo(map_a4a57f58baea1ce0cbbe41566361ca8b);
#
#
#         var popup_ac4d166527e1e14f711a9a4ba417caaa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_910dba318eecfd5d5db3017256197cf1 = $(`&lt;div id=&quot;html_910dba318eecfd5d5db3017256197cf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;118409&lt;/div&gt;`)[0];
#                 popup_ac4d166527e1e14f711a9a4ba417caaa.setContent(html_910dba318eecfd5d5db3017256197cf1);
#
#
#
#         marker_507aa3791de693dd5db458affd67e24c.bindPopup(popup_ac4d166527e1e14f711a9a4ba417caaa)
#         ;
#
#
#
#
#             var marker_51c4606dc6dd0b4a54e763e5262bd65a = L.marker(
#                 [42.5407167, 1.5732033],
#                 {
# }
#             ).addTo(map_a4a57f58baea1ce0cbbe41566361ca8b);
#
#
#         var popup_d0b31e3444c22676982aa23fe5673563 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f588d6e1d7d549b5c82fddaf6e8ebeb = $(`&lt;div id=&quot;html_0f588d6e1d7d549b5c82fddaf6e8ebeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;14380&lt;/div&gt;`)[0];
#                 popup_d0b31e3444c22676982aa23fe5673563.setContent(html_0f588d6e1d7d549b5c82fddaf6e8ebeb);
#
#
#
#         marker_51c4606dc6dd0b4a54e763e5262bd65a.bindPopup(popup_d0b31e3444c22676982aa23fe5673563)
#         ;
#
#
#
#
#             var marker_09f62f038fc7997a7e486943f7e12122 = L.marker(
#                 [-11.8775768, 17.5691241],
#                 {
# }
#             ).addTo(map_a4a57f58baea1ce0cbbe41566361ca8b);
#
#
#         var popup_2eea047ed331a7280d2323ad49aca2ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe12e70f40a41c015525b94e00d55bcd = $(`&lt;div id=&quot;html_fe12e70f40a41c015525b94e00d55bcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;39582&lt;/div&gt;`)[0];
#                 popup_2eea047ed331a7280d2323ad49aca2ef.setContent(html_fe12e70f40a41c015525b94e00d55bcd);
#
#
#
#         marker_09f62f038fc7997a7e486943f7e12122.bindPopup

# %%
m = folium.Map(location=[54, 15], zoom_start=2)

for id, row in df.iterrows():
    folium.Marker(location=[row['lat'], row['lon']], popup=row['Deaths']).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_443e1ab4f2289929ef262a55f2e7b5cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_443e1ab4f2289929ef262a55f2e7b5cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_443e1ab4f2289929ef262a55f2e7b5cd = L.map(
#                 &quot;map_443e1ab4f2289929ef262a55f2e7b5cd&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_130316066e079429dc6446d4f147d2e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_130316066e079429dc6446d4f147d2e8.addTo(map_443e1ab4f2289929ef262a55f2e7b5cd);
#
#
#             var marker_bac6f1ace956245909084a397261111f = L.marker(
#                 [33.7680065, 66.2385139],
#                 {
# }
#             ).addTo(map_443e1ab4f2289929ef262a55f2e7b5cd);
#
#
#         var popup_87cd5c16e36337241c24999d900182eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3aa1b8fdd68bc82136eb0bfb2a29c68d = $(`&lt;div id=&quot;html_3aa1b8fdd68bc82136eb0bfb2a29c68d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;7676&lt;/div&gt;`)[0];
#                 popup_87cd5c16e36337241c24999d900182eb.setContent(html_3aa1b8fdd68bc82136eb0bfb2a29c68d);
#
#
#
#         marker_bac6f1ace956245909084a397261111f.bindPopup(popup_87cd5c16e36337241c24999d900182eb)
#         ;
#
#
#
#
#             var marker_d2d267c11cde81bad40e1e7742af39a3 = L.marker(
#                 [41.000028, 19.9999619],
#                 {
# }
#             ).addTo(map_443e1ab4f2289929ef262a55f2e7b5cd);
#
#
#         var popup_8c86e4061068b0edd0b98a0993f3db5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf6bfcaab3c69a63e66e3d1ff0346a26 = $(`&lt;div id=&quot;html_bf6bfcaab3c69a63e66e3d1ff0346a26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3496&lt;/div&gt;`)[0];
#                 popup_8c86e4061068b0edd0b98a0993f3db5d.setContent(html_bf6bfcaab3c69a63e66e3d1ff0346a26);
#
#
#
#         marker_d2d267c11cde81bad40e1e7742af39a3.bindPopup(popup_8c86e4061068b0edd0b98a0993f3db5d)
#         ;
#
#
#
#
#             var marker_e4d8c945b9109c09fe965823cd1c0cb5 = L.marker(
#                 [28.0000272, 2.9999825],
#                 {
# }
#             ).addTo(map_443e1ab4f2289929ef262a55f2e7b5cd);
#
#
#         var popup_9ef293bea03f6ac26e537c3d49d9cf2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2a44d62efe735166784d82d55a02234 = $(`&lt;div id=&quot;html_b2a44d62efe735166784d82d55a02234&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6874&lt;/div&gt;`)[0];
#                 popup_9ef293bea03f6ac26e537c3d49d9cf2c.setContent(html_b2a44d62efe735166784d82d55a02234);
#
#
#
#         marker_e4d8c945b9109c09fe965823cd1c0cb5.bindPopup(popup_9ef293bea03f6ac26e537c3d49d9cf2c)
#         ;
#
#
#
#
#             var marker_0b054125d8798e3ba61986f1b24ce185 = L.marker(
#                 [42.5407167, 1.5732033],
#                 {
# }
#             ).addTo(map_443e1ab4f2289929ef262a55f2e7b5cd);
#
#
#         var popup_58d9ba06b942b7db538f5fb76d20f6ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e3d23f29c71ae316f85da4ae86f0d1b = $(`&lt;div id=&quot;html_1e3d23f29c71ae316f85da4ae86f0d1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;155&lt;/div&gt;`)[0];
#                 popup_58d9ba06b942b7db538f5fb76d20f6ec.setContent(html_1e3d23f29c71ae316f85da4ae86f0d1b);
#
#
#
#         marker_0b054125d8798e3ba61986f1b24ce185.bindPopup(popup_58d9ba06b942b7db538f5fb76d20f6ec)
#         ;
#
#
#
#
#             var marker_2b0cd056a5e6b4b71fb05fc384af9bbf = L.marker(
#                 [-11.8775768, 17.5691241],
#                 {
# }
#             ).addTo(map_443e1ab4f2289929ef262a55f2e7b5cd);
#
#
#         var popup_471b9c5b49d67087c613c5a192db60a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72361ad75a1127a744b8120397d3a924 = $(`&lt;div id=&quot;html_72361ad75a1127a744b8120397d3a924&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1900&lt;/div&gt;`)[0];
#                 popup_471b9c5b49d67087c613c5a192db60a8.setContent(html_72361ad75a1127a744b8120397d3a924);
#
#
#
#         marker_2b0cd056a5e6b4b71fb05fc384af9bbf.bindPopup(popup_4

# %% [markdown]
# ### Plot Deaths using Marker Cluster

# %%
from folium.plugins import MarkerCluster
mc = MarkerCluster()

# %%
m = folium.Map(location=[54, 15], tiles='openstreetmap', zoom_start=2)

for id, row in df.iterrows():
    mc.add_child(folium.Marker(location=[row['lat'], row['lon']], popup=row['Deaths']))

m.add_child(mc)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ad22a20c6cca2ad0d7de113648485ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ad22a20c6cca2ad0d7de113648485ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ad22a20c6cca2ad0d7de113648485ba = L.map(
#                 &quot;map_1ad22a20c6cca2ad0d7de113648485ba&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e57f8316a6289355456073685754320f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e57f8316a6289355456073685754320f.addTo(map_1ad22a20c6cca2ad0d7de113648485ba);
#
#
#             var marker_cluster_43aca4963cb6647849eb362cc1b51834 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_b82272848461dcc07bf48fa70649f69a = L.marker(
#                 [33.7680065, 66.2385139],
#                 {
# }
#             ).addTo(marker_cluster_43aca4963cb6647849eb362cc1b51834);
#
#
#         var popup_8516a505195a3a89ff5c3b7996854697 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5f435872964a0b21f2224eb47888847 = $(`&lt;div id=&quot;html_c5f435872964a0b21f2224eb47888847&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;7676&lt;/div&gt;`)[0];
#                 popup_8516a505195a3a89ff5c3b7996854697.setContent(html_c5f435872964a0b21f2224eb47888847);
#
#
#
#         marker_b82272848461dcc07bf48fa70649f69a.bindPopup(popup_8516a505195a3a89ff5c3b7996854697)
#         ;
#
#
#
#
#             var marker_249ff1c2afe5c9d9d8b9717bde893843 = L.marker(
#                 [41.000028, 19.9999619],
#                 {
# }
#             ).addTo(marker_cluster_43aca4963cb6647849eb362cc1b51834);
#
#
#         var popup_983026dfd1e24e427fdd1bdb93509673 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3569d80727378a7b595ef3de81285d9 = $(`&lt;div id=&quot;html_d3569d80727378a7b595ef3de81285d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3496&lt;/div&gt;`)[0];
#                 popup_983026dfd1e24e427fdd1bdb93509673.setContent(html_d3569d80727378a7b595ef3de81285d9);
#
#
#
#         marker_249ff1c2afe5c9d9d8b9717bde893843.bindPopup(popup_983026dfd1e24e427fdd1bdb93509673)
#         ;
#
#
#
#
#             var marker_e91d1dc75e82f09e71c817a2710ee8a5 = L.marker(
#                 [28.0000272, 2.9999825],
#                 {
# }
#             ).addTo(marker_cluster_43aca4963cb6647849eb362cc1b51834);
#
#
#         var popup_dd45f83da2a4c101abaefc146b3c8de8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91a180a86e19ab037025f05a2d700248 = $(`&lt;div id=&quot;html_91a180a86e19ab037025f05a2d700248&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6874&lt;/div&gt;`)[0];
#                 popup_dd45f83da2a4c101abaefc146b3c8de8.setContent(html_91a180a86e19ab037025f05a2d700248);
#
#
#
#         marker_e91d1dc75e82f09e71c817a2710ee8a5.bindPopup(popup_dd45f83da2a4c101abaefc146b3c8de8)
#         ;
#
#
#
#
#             var marker_c0ff9e8f2a4f4cfe5854e69da50caa2f = L.marker(
#                 [42.5407167, 1.5732033],
#                 {
# }
#             ).addTo(marker_cluster_43aca4963cb6647849eb362cc1b51834);
#
#
#         var popup_8d2967e1a8a334c44b86fb44b47769f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f751ba6a6602b67c42fd1995f8cc41d = $(`&lt;div id=&quot;html_0f751ba6a6602b67c42fd1995f8cc41d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;155&lt;/div&gt;`)[0];
#                 popup_8d2967e1a8a334c44b86fb44b47769f8.setContent(html_0f751ba6a6602b67c42fd1995f8cc41d);
#
#
#
#         marker_c0ff9e8f2a4f4cfe5854e69da50caa2f.bindPopup(popup_8d2967e1a8a334c44b86fb44b47769f8)
#         ;
#
#
#
#
#             var marker_8c97a4d8279c0086ce32aca368bb295d = L.marker(
#                 [-11.8775768, 17.569

# %% [markdown]
# ### Geographic Heatmap of Confirmed Cases

# %%
from folium.plugins import HeatMap

# %%
df.head()
# Out:
#        Country  Confirmed  Recovered  Deaths        lat        lon
# 0  Afghanistan     178387      82586    7676  33.768006  66.238514
# 1      Albania     274462     130314    3496  41.000028  19.999962
# 2      Algeria     265739     118409    6874  28.000027   2.999983
# 3      Andorra      40709      14380     155  42.540717   1.573203
# 4       Angola      99194      39582    1900 -11.877577  17.569124

# %%
m = folium.Map(location=[54, 15], tiles='openstreetmap', zoom_start=2)

HeatMap(data=df[['lat', 'lon', 'Confirmed']], radius=15).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5feca5013076bb6c3819e4ab8335b2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5feca5013076bb6c3819e4ab8335b2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5feca5013076bb6c3819e4ab8335b2f = L.map(
#                 &quot;map_b5feca5013076bb6c3819e4ab8335b2f&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5753e70927417aa6058cc56b6058741c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5753e70927417aa6058cc56b6058741c.addTo(map_b5feca5013076bb6c3819e4ab8335b2f);
#
#
#             var heat_map_59a1ee2f7d76dc98525ef4a82c975955 = L.heatLayer(
#                 [[33.7680065, 66.2385139, 178387.0], [41.000028, 19.9999619, 274462.0], [28.0000272, 2.9999825, 265739.0], [42.5407167, 1.5732033, 40709.0], [-11.8775768, 17.5691241, 99194.0], [-72.8438691, 0.0, 11.0], [17.2234721, -61.9554608, 7535.0], [-34.9964963, -64.9672817, 9060495.0], [40.7696272, 44.6736646, 422747.0], [-24.7761086, 134.755, 5384615.0], [47.59397, 14.12456, 4045809.0], [40.3936294, 47.7872508, 792349.0], [24.7736546, -78.0000547, 33391.0], [26.1551249, 50.5344606, 562759.0], [24.4769288, 90.2934413, 1952275.0], [13.1500331, -59.5250305, 64348.0], [53.4250605, 27.6971358, 974046.0], [50.6402809, 4.6667145, 3972963.0], [17.1204943, -88.6859028, 57331.0], [9.5293472, 2.2584408, 26952.0], [27.549511, 90.5119273, 51800.0], [-17.0568696, -64.9912286, 903888.0], [44.3053476, 17.5961467, 376437.0], [-23.1681782, 24.5928742, 305859.0], [-10.3333333, -53.2, 30250077.0], [4.4137155, 114.5653908, 139847.0], [42